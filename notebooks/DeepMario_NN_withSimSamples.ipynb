# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import *
from keras.optimizers import Adam
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/hd/b3xdbhj91fj7d7_gq2f0v1h40000gn/T/ipykernel_13129/670482908.py in <module>
#       6 from keras.models import Sequential
#       7 from keras.layers import *
# ----> 8 from keras.optimizers import Adam
#       9 import tensorflow as tf
#
# ImportError: cannot import name 'Adam' from 'keras.optimizers' (/Users/isaaclera/.pyenv/versions/mypy397/lib/python3.9/site-packages/keras/optimizers.py)

# %%
df = pd.read_csv("../results/results_SmallFog_X/samples.csv")
df.head()
# Out:
#    sim  app currentFlavour     action  HWreq  OdiffReqChannels  OreqChannels  \
# 0    0    1         medium   undeploy     10                 1             1
# 1    0    1         medium      small     10                 1             1
# 2    0    1         medium      large     10                 1             1
# 3    0    1          small   undeploy      5                 1             1
# 4    0    1          small  replicate      5                 1             1
#
#    OsumReq  OavgReq  OsumLat  ...  FavgReq  FsumLat  FavgLat  FHWtotal  \
# 0        2      2.0        4  ...      0.0        0      0.0       2.0
# 1        3      3.0        4  ...      1.0        4      4.0       2.0
# 2        1      1.0        4  ...      2.0        4      4.0       2.0
# 3        2      2.0        7  ...      0.0        0      0.0       6.0
# 4        1      1.0        7  ...      0.0        0      0.0       6.0
#
#    FHWfree  Futilization  Fdegree  Fcentrality  Fnusers  fit
# 0        0      1.000000        1     0.076923        1  0.0
# 1        1      0.500000        1     0.076923        1  1.0
# 2       -3      2.500000        1     0.076923        1  0.0
# 3        4      0.333333        4     0.307692        1  0.0
# 4        4      0.333333        4     0.307692        1  1.0
#
# [5 rows x 31 columns]
